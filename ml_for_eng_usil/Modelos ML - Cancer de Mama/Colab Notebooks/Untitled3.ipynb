# %%
import pandas as pd

# %%
Rows = [['California Girls','Platinum','Katy Perry'],['Blinding Eyes','Silver','The Weekend'],['Let It Be','Gold','The Beatles']]
Columns = ['SongName','MaxAchieve','Artist']
TestDF = pd.DataFrame(Rows,columns = Columns)

# %%
df = pd.read_csv('https://raw.githubusercontent.com/MicrosoftDocs/mslearn-introduction-to-machine-learning/main/Data/ml-basics/grades.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        24 non-null     object
#  1   StudyHours  23 non-null     float64
#  2   Grade       22 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 704.0+ bytes

# %%
df.head()
# Out:
#     Name  StudyHours  Grade
# 0    Dan       10.00   50.0
# 1  Joann       11.50   50.0
# 2  Pedro        9.00   47.0
# 3  Rosie       16.00   97.0
# 4  Ethan        9.25   49.0

# %%
df[['Grade']].describe()
# Out:
#            Grade
# count  22.000000
# mean   49.181818
# std    21.737912
# min     3.000000
# 25%    36.250000
# 50%    49.500000
# 75%    62.750000
# max    97.000000

# %%
df[['Grade']].mean()
# Out:
# Grade    49.181818
# dtype: float64

# %%
df.groupby('Name')[['Grade','StudyHours']].mean().sort_values(by=['StudyHours'], ascending = False)
# Out:
#            Grade  StudyHours
# Name
# Rosie       97.0       16.00
# Francesca   82.0       15.50
# Jenny       70.0       15.50
# Giovanni    74.0       14.50
# Rajab       62.0       13.75
# Daniel      63.0       12.50
# Aisha       64.0       12.00
# Skye        52.0       12.00
# Joann       50.0       11.50
# Frederic    53.0       11.50
# Dan         50.0       10.00
# Anila       48.0       10.00
# Ethan       49.0        9.25
# Naiyana     37.0        9.00
# Helena      36.0        9.00
# Jimmie      42.0        9.00
# Pedro       47.0        9.00
# Rhonda      26.0        8.50
# Jakeem      27.0        8.00
# Kian        15.0        8.00
# Bill         NaN        8.00
# Ismat       35.0        6.00
# Vicky        3.0        1.00
# Ted          NaN         NaN

# %%
df.groupby('Name')[['Grade','StudyHours']].agg(['mean','median','min','max'])
# Out:
#           Grade                    StudyHours
#            mean median   min   max       mean median    min    max
# Name
# Aisha      64.0   64.0  64.0  64.0      12.00  12.00  12.00  12.00
# Anila      48.0   48.0  48.0  48.0      10.00  10.00  10.00  10.00
# Bill        NaN    NaN   NaN   NaN       8.00   8.00   8.00   8.00
# Dan        50.0   50.0  50.0  50.0      10.00  10.00  10.00  10.00
# Daniel     63.0   63.0  63.0  63.0      12.50  12.50  12.50  12.50
# Ethan      49.0   49.0  49.0  49.0       9.25   9.25   9.25   9.25
# Francesca  82.0   82.0  82.0  82.0      15.50  15.50  15.50  15.50
# Frederic   53.0   53.0  53.0  53.0      11.50  11.50  11.50  11.50
# Giovanni   74.0   74.0  74.0  74.0      14.50  14.50  14.50  14.50
# Helena     36.0   36.0  36.0  36.0       9.00   9.00   9.00   9.00
# Ismat      35.0   35.0  35.0  35.0       6.00   6.00   6.00   6.00
# Jakeem     27.0   27.0  27.0  27.0       8.00   8.00   8.00   8.00
# ...

# %%
df.plot(kind='scatter', x='Grade', y='StudyHours', color = 'Red')

# %%
df['Grade'].plot(kind='hist')

# %%
df.pivot(columns = 'Name', values= 'Grade').plot(kind = 'box', figsize = (5,2))

# %%
RomeveNull = df.dropna(subset = ['Grade','StudyHours'], how = 'all')

# %%
display(RomeveNull.sort_values(by='Grade', ascending = False))
# Out:
#          Name  StudyHours  Grade
# 3       Rosie       16.00   97.0
# 10  Francesca       15.50   82.0
# 9    Giovanni       14.50   74.0
# 14      Jenny       15.50   70.0
# 21      Aisha       12.00   64.0
# 20     Daniel       12.50   63.0
# 11      Rajab       13.75   62.0
# 6    Frederic       11.50   53.0
# 19       Skye       12.00   52.0
# 1       Joann       11.50   50.0
# 0         Dan       10.00   50.0
# 4       Ethan        9.25   49.0
# 18      Anila       10.00   48.0
# 2       Pedro        9.00   47.0
# 7      Jimmie        9.00   42.0
# 12    Naiyana        9.00   37.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 15     Jakeem        8.00   27.0
# 8      Rhonda        8.50   26.0
# 13       Kian        8.00   15.0
# 5       Vicky        1.00    3.0
# 22       Bill        8.00    NaN

# %%
axis1 = RomeveNull.dropna(axis=1, thresh = 10)
axis1
# Out:
#          Name  StudyHours  Grade
# 0         Dan       10.00   50.0
# 1       Joann       11.50   50.0
# 2       Pedro        9.00   47.0
# 3       Rosie       16.00   97.0
# 4       Ethan        9.25   49.0
# 5       Vicky        1.00    3.0
# 6    Frederic       11.50   53.0
# 7      Jimmie        9.00   42.0
# 8      Rhonda        8.50   26.0
# 9    Giovanni       14.50   74.0
# 10  Francesca       15.50   82.0
# 11      Rajab       13.75   62.0
# 12    Naiyana        9.00   37.0
# 13       Kian        8.00   15.0
# 14      Jenny       15.50   70.0
# 15     Jakeem        8.00   27.0
# 16     Helena        9.00   36.0
# 17      Ismat        6.00   35.0
# 18      Anila       10.00   48.0
# 19       Skye       12.00   52.0
# 20     Daniel       12.50   63.0
# 21      Aisha       12.00   64.0
# 22       Bill        8.00    NaN

# %%
FillNullValues = df.fillna({'StudyHours':0.00, 'Grade':0.0})
FillNullValues.sort_values(by=['Grade','StudyHours'], ascending = [True,False])

# %%
Filter = (FillNullValues['StudyHours'] >=10) & (FillNullValues['Grade'] < 70)
Filter

# %%
df1 = FillNullValues.loc[Filter,:]
df1
# Out:
#         Name  StudyHours  Grade
# 0        Dan       10.00   50.0
# 1      Joann       11.50   50.0
# 6   Frederic       11.50   53.0
# 11     Rajab       13.75   62.0
# 18     Anila       10.00   48.0
# 19      Skye       12.00   52.0
# 20    Daniel       12.50   63.0
# 21     Aisha       12.00   64.0

# %%
df2 = df1.loc[Filter,'StudyHours'] = 10.00
df1
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
#         Name  StudyHours  Grade
# 0        Dan        10.0   50.0
# 1      Joann        10.0   50.0
# 6   Frederic        10.0   53.0
# 11     Rajab        10.0   62.0
# 18     Anila        10.0   48.0
# 19      Skye        10.0   52.0
# 20    Daniel        10.0   63.0
# 21     Aisha        10.0   64.0
