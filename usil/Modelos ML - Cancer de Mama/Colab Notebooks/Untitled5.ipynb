# %%
# !pip install pyspark
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 316.9/316.9 MB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pyspark: filename=pyspark-3.5.0-py2.py3-none-any.whl size=317425344 sha256=b2661a6e3620de8c1cc00d4cf75003b2b5e71a52d37e6a0d26f3c6b1439a31de
#   Stored in directory: /root/.cache/pip/wheels/41/4e/10/c2cf2467f71c678cfc8a6b9ac9241e5e44a01940da8fbb17fc
# Successfully built pyspark
# ...

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('abc').getOrCreate()

# %%
import pyspark
import pandas as pd
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType,StructField, StringType, IntegerType

# %%
dataconsultas = "[{'ClusterNodeType':'Standard_F4','ClusterNodeTypeDriver':'Standard_F4','ClusterAccessMode':'LEGACY_TABLE_ACL','ClusterSource':'JOB','ClusterSparkVersion':'13.1.x-scala2.12','ClusterAvailability':'ON_DEMAND_AZURE','ClusterRuntimeEngine':'STANDARD','ClusterMinWorkers':1,'ClusterMaxWorker':4,'EndRange':50},{'ClusterNodeType':'Standard_DS3_v2','ClusterNodeTypeDriver':'Standard_DS3_v2','ClusterAccessMode':'LEGACY_TABLE_ACL','ClusterSource':'JOB','ClusterSparkVersion':'13.1.x-scala2.12','ClusterAvailability':'ON_DEMAND_AZURE','ClusterRuntimeEngine':'STANDARD','ClusterMinWorkers':1,'ClusterMaxWorker':4,'EndRange':150},{'ClusterNodeType':'Standard_E8d_v4','ClusterNodeTypeDriver':'Standard_E8d_v4','ClusterAccessMode':'LEGACY_TABLE_ACL','ClusterSource':'JOB','ClusterSparkVersion':'13.1.x-scala2.12','ClusterAvailability':'ON_DEMAND_AZURE','ClusterRuntimeEngine':'STANDARD','ClusterMinWorkers':1,'ClusterMaxWorker':4,'EndRange':9999}]"

# %%
data =  eval(dataconsultas)
Pandasdf = pd.DataFrame(data)
display(Pandasdf)
# Out:
#    ClusterNodeType ClusterNodeTypeDriver ClusterAccessMode ClusterSource  \
# 0      Standard_F4           Standard_F4  LEGACY_TABLE_ACL           JOB
# 1  Standard_DS3_v2       Standard_DS3_v2  LEGACY_TABLE_ACL           JOB
# 2  Standard_E8d_v4       Standard_E8d_v4  LEGACY_TABLE_ACL           JOB
#
#   ClusterSparkVersion ClusterAvailability ClusterRuntimeEngine  \
# 0    13.1.x-scala2.12     ON_DEMAND_AZURE             STANDARD
# 1    13.1.x-scala2.12     ON_DEMAND_AZURE             STANDARD
# 2    13.1.x-scala2.12     ON_DEMAND_AZURE             STANDARD
#
#    ClusterMinWorkers  ClusterMaxWorker  EndRange
# 0                  1                 4        50
# 1                  1                 4       150
# 2                  1                 4      9999

# %%
sparkDF=spark.createDataFrame(Pandasdf)
sparkDF.show()
# Out:
# +---------------+---------------------+-----------------+-------------+-------------------+-------------------+--------------------+-----------------+----------------+--------+
# |ClusterNodeType|ClusterNodeTypeDriver|ClusterAccessMode|ClusterSource|ClusterSparkVersion|ClusterAvailability|ClusterRuntimeEngine|ClusterMinWorkers|ClusterMaxWorker|EndRange|
# +---------------+---------------------+-----------------+-------------+-------------------+-------------------+--------------------+-----------------+----------------+--------+
# |    Standard_F4|          Standard_F4| LEGACY_TABLE_ACL|          JOB|   13.1.x-scala2.12|    ON_DEMAND_AZURE|            STANDARD|                1|               4|      50|
# |Standard_DS3_v2|      Standard_DS3_v2| LEGACY_TABLE_ACL|          JOB|   13.1.x-scala2.12|    ON_DEMAND_AZURE|            STANDARD|                1|               4|     150|
# ...

# %%
CountSparkDF = sparkDF.count()
print("el conteo es "+str(CountSparkDF))
# Out:
# el conteo es 3
